# %% [markdown]
# # Module 1 Project: Core Vision Tasks and Metrics
#
#
# > **Colab setup:** This notebook uses only the default open-source Python stack available in Google Colab: NumPy, Matplotlib, and scikit-learn. No `pip install`, no API keys, and no external authorization are required.
# >
# > **How to work:** Complete only the `TODO` lines. Most cells are partially written so you practice the key ideas without building everything from scratch.

# %% [markdown]
# ## Learning goals
# - Load and visualize image data
# - Train a simple image classifier
# - Complete accuracy, IoU, and Dice formulas
# - Build a small tracking-style centroid visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

np.random.seed(7)
digits = load_digits()
X_images = digits.images
y = digits.target
X = X_images.reshape(len(X_images), -1)

print(X_images.shape, X.shape, y.shape)

# %%
# TODO 1: visualize the first 20 digit images.
fig, axes = plt.subplots(4, 5, figsize=(9, 6))
for ax, img, label in zip(axes.ravel(), X_images[:20], y[:20]):
    ax.imshow(____, cmap="gray")
    ax.set_title(f"label={____}")
    ax.axis("off")
plt.tight_layout()
plt.show()

# %%
# TODO 2: train a compact classifier.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=____, random_state=7, stratify=y
)
scaler = StandardScaler()
X_train_s = scaler.fit_transform(____)
X_test_s = scaler.transform(____)

clf = LogisticRegression(max_iter=800, solver="lbfgs", multi_class="auto")
clf.fit(____, ____)
y_pred = clf.predict(____)
print("Accuracy:", np.mean(y_pred == y_test))

# %%
# TODO 3: complete the accuracy equation.
def accuracy(y_true, y_pred):
    return ____

print("Manual accuracy:", accuracy(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot(cmap="Blues", values_format="d")
plt.title("Confusion matrix")
plt.show()

# %%
# TODO 4: complete IoU and Dice for segmentation masks.
mask_a = np.zeros((32, 32), dtype=bool)
mask_b = np.zeros((32, 32), dtype=bool)
mask_a[8:24, 9:24] = True
mask_b[11:27, 13:28] = True

def iou(pred, gt):
    intersection = np.logical_and(pred, gt).sum()
    union = ____
    return intersection / union

def dice(pred, gt):
    intersection = np.logical_and(pred, gt).sum()
    return ____

print("IoU:", iou(mask_b, mask_a))
print("Dice:", dice(mask_b, mask_a))

fig, axes = plt.subplots(1, 3, figsize=(10, 3))
axes[0].imshow(mask_a, cmap="gray"); axes[0].set_title("Ground truth")
axes[1].imshow(mask_b, cmap="gray"); axes[1].set_title("Prediction")
axes[2].imshow(mask_a.astype(int) + mask_b.astype(int), cmap="viridis"); axes[2].set_title("Overlap")
for ax in axes: ax.axis("off")
plt.show()

# %%
# TODO 5: complete the centroid tracking simulation.
centers = []
for t in range(10):
    x = 5 + 2.5 * t
    y_pos = 8 + 1.5 * t
    centers.append((____, ____))
centers = np.array(centers)

plt.figure(figsize=(5, 5))
plt.plot(centers[:, 0], centers[:, 1], marker="o")
for t, (x, y_pos) in enumerate(centers):
    plt.text(x + 0.2, y_pos, str(t))
plt.gca().invert_yaxis()
plt.title("Simple tracking: centroid over time")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
